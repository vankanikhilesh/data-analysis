# %%
import pandas as pd #for importing dataset
import numpy as nm #for doing mathematical operations
from sklearn.model_selection import train_test_split as ttp #to break dataset for training and testing
from sklearn.metrics import classification_report # to generate classification report
import re #for data cleaning purpose
import string #to deal with text data
import matplotlib.pyplot as plt #for visualizing dataset

# %%
data_true=pd.read_csv("/content/drive/MyDrive/passingers/passeneger/train.csv")
data_fake=pd.read_csv("/content/drive/MyDrive/passingers/passeneger/test.csv")

# %%
data_true.head(5)
data_fake.head(5)
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# 2                                  0  ...                       2
# 3                                  0  ...                       1
# 4                                  3  ...                       2
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 5                 5                 5                2
# 1                 4                 4                 4                3
# 2                 4                 1                 3                2
# 3                 1                 1                 1                3
# 4                 2                 2                 2                4
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          50
# 1                 4            5                           0
# 2                 2            2                           0
# 3                 1            4                           0
# 4                 2            4                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      44.0                satisfied
# 1                       0.0                satisfied
# 2                       0.0  neutral or dissatisfied
# 3                       6.0                satisfied
# 4                      20.0                satisfied
#
# [5 rows x 25 columns]

# %%
data_true.shape, data_fake.shape
data_true["class"]=1
data_fake["class"]=0

# %%
data_true_manual_testing = data_true.tail(10)
for i in range(25965,25955,-1):
    data_true.drop([i],axis=0, inplace=True)#removing those 10 values from original dataset

data_fake_manual_testing = data_fake.tail(10)
for i in range(25965,25955,-1):
    data_fake.drop([i],axis=0, inplace=True)#removing those 10 values from original datas

# %%
data_manual_testing = pd.concat([data_fake_manual_testing, data_true_manual_testing], axis=0)
data_manual_testing.to_csv("manual_testing.csv ")

# %%
data_merge = pd.concat([data_fake,data_true],axis=0)
data_merge.head(10)#displaying first 10 values after above operation
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
# 5           5  39177    Male     Loyal Customer   16  Business travel
# 6           6  79433  Female     Loyal Customer   77  Business travel
# 7           7  97286  Female     Loyal Customer   43  Business travel
# 8           8  27508    Male     Loyal Customer   47  Business travel
# 9           9  62482  Female     Loyal Customer   46  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
# 5       Eco              311                      3
# 6  Business             3987                      5
# 7  Business             2556                      2
# 8       Eco              556                      5
# 9  Business             1744                      2
#
#    Departure/Arrival time convenient  ...  On-board service  Leg room service  \
# 0                                  4  ...                 5                 5
# 1                                  1  ...                 4                 4
# 2                                  0  ...                 4                 1
# 3                                  0  ...                 1                 1
# 4                                  3  ...                 2                 2
# 5                                  3  ...                 4                 3
# 6                                  5  ...                 5                 5
# 7                                  2  ...                 4                 4
# 8                                  2  ...                 2                 2
# 9                                  2  ...                 4                 4
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 5                2                 5            5
# 1                 4                3                 4            5
# 2                 3                2                 2            2
# 3                 1                3                 1            4
# 4                 2                4                 2            4
# 5                 1                1                 2            5
# 6                 5                4                 5            3
# 7                 4                5                 4            3
# 8                 5                3                 3            5
# 9                 4                5                 4            4
#
#    Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                          50                      44.0
# 1                           0                       0.0
# 2                           0                       0.0
# 3                           0                       6.0
# 4                           0                      20.0
# 5                           0                       0.0
# 6                           0                       0.0
# 7                          77                      65.0
# 8                           1                       0.0
# 9                          28                      14.0
#
#               satisfaction  class
# 0                satisfied      0
# 1                satisfied      0
# 2  neutral or dissatisfied      0
# 3                satisfied      0
# 4                satisfied      0
# 5                satisfied      0
# 6                satisfied      0
# 7                satisfied      0
# 8                satisfied      0
# 9                satisfied      0
#
# [10 rows x 26 columns]

# %%
print(data_merge.groupby(['Gender'])['class'].count())
data_merge.groupby(['Gender'])['class'].count().plot(kind="bar")
plt.title("Airline passenger satisfaction",size=20)
plt.xlabel(" GEnder",size=20)
plt.ylabel("class",size=20)
plt.show()
# Out:
# Gender
# Female    65886
# Male      63974
# Name: class, dtype: int64

# %%
print(data_merge.groupby(['class'])['class'].count())
print("0 = Fake news\n1 = True news")
data_merge.groupby(['class'])['class'].count().plot(kind="pie")
plt.title("Fake news and True News",size=20)
plt.show()
# Out:
# class
# 0     25966
# 1    103894
# Name: class, dtype: int64
# 0 = Fake news
# 1 = True news

# %%
data = data_merge.drop(["Customer Type","Gender","id"], axis=1)
data.head(10) #displaying remaining dataset
# Out:
#    Unnamed: 0  Age   Type of Travel     Class  Flight Distance  \
# 0           0   52  Business travel       Eco              160
# 1           1   36  Business travel  Business             2863
# 2           2   20  Business travel       Eco              192
# 3           3   44  Business travel  Business             3377
# 4           4   49  Business travel       Eco             1182
# 5           5   16  Business travel       Eco              311
# 6           6   77  Business travel  Business             3987
# 7           7   43  Business travel  Business             2556
# 8           8   47  Business travel       Eco              556
# 9           9   46  Business travel  Business             1744
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      5                                  4
# 1                      1                                  1
# 2                      2                                  0
# 3                      0                                  0
# 4                      2                                  3
# 5                      3                                  3
# 6                      5                                  5
# 7                      2                                  2
# 8                      5                                  2
# 9                      2                                  2
#
#    Ease of Online booking  Gate location  Food and drink  ...  \
# 0                       3              4               3  ...
# 1                       3              1               5  ...
# 2                       2              4               2  ...
# 3                       0              2               3  ...
# 4                       4              3               4  ...
# 5                       3              3               5  ...
# 6                       5              5               3  ...
# 7                       2              2               4  ...
# 8                       2              2               5  ...
# 9                       2              2               3  ...
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 5                 5                 5                2
# 1                 4                 4                 4                3
# 2                 4                 1                 3                2
# 3                 1                 1                 1                3
# 4                 2                 2                 2                4
# 5                 4                 3                 1                1
# 6                 5                 5                 5                4
# 7                 4                 4                 4                5
# 8                 2                 2                 5                3
# 9                 4                 4                 4                5
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          50
# 1                 4            5                           0
# 2                 2            2                           0
# 3                 1            4                           0
# 4                 2            4                           0
# 5                 2            5                           0
# 6                 5            3                           0
# 7                 4            3                          77
# 8                 3            5                           1
# 9                 4            4                          28
#
#    Arrival Delay in Minutes             satisfaction  class
# 0                      44.0                satisfied      0
# 1                       0.0                satisfied      0
# 2                       0.0  neutral or dissatisfied      0
# 3                       6.0                satisfied      0
# 4                      20.0                satisfied      0
# 5                       0.0                satisfied      0
# 6                       0.0                satisfied      0
# 7                      65.0                satisfied      0
# 8                       0.0                satisfied      0
# 9                      14.0                satisfied      0
#
# [10 rows x 23 columns]

# %%
data=data.sample(frac=1)
data.head(10)
# Out:
#         Unnamed: 0  Age   Type of Travel     Class  Flight Distance  \
# 62305        62305   39  Business travel       Eco              160
# 60508        60508   27  Business travel  Business             1337
# 100718      100718   66  Business travel  Eco Plus              351
# 103587      103587   43  Business travel       Eco              366
# 6786          6786   47  Business travel  Business             2521
# 70969        70969   61  Personal Travel       Eco              948
# 4185          4185   53  Business travel       Eco              577
# 27067        27067   46  Business travel       Eco              544
# 55447        55447   30  Business travel  Eco Plus              483
# 39968        39968   36  Personal Travel       Eco              862
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# 62305                       4                                  4
# 60508                       3                                  4
# 100718                      2                                  3
# 103587                      4                                  4
# 6786                        3                                  3
# 70969                       2                                  0
# 4185                        1                                  0
# 27067                       4                                  3
# 55447                       0                                  0
# 39968                       2                                  5
#
#         Ease of Online booking  Gate location  Food and drink  ...  \
# 62305                        4              4               4  ...
# 60508                        4              2               2  ...
# 100718                       3              3               2  ...
# 103587                       4              4               4  ...
# 6786                         3              3               4  ...
# 70969                        2              4               4  ...
# 4185                         0              3               4  ...
# 27067                        3              3               4  ...
# 55447                        0              3               1  ...
# 39968                        2              5               2  ...
#
#         On-board service  Leg room service  Baggage handling  Checkin service  \
# 62305                  1                 5                 5                3
# 60508                  3                 4                 4                3
# 100718                 4                 5                 4                1
# 103587                 2                 4                 4                4
# 6786                   2                 4                 4                4
# 70969                  3                 2                 5                3
# 4185                   4                 4                 2                2
# 27067                  4                 4                 4                1
# 55447                  4                 1                 5                2
# 39968                  3                 4                 4                1
#
#         Inflight service  Cleanliness  Departure Delay in Minutes  \
# 62305                  1            4                           0
# 60508                  5            2                          23
# 100718                 3            2                           0
# 103587                 3            4                           0
# 6786                   3            4                           0
# 70969                  5            4                           0
# 4185                   2            4                           0
# 27067                  4            2                           0
# 55447                  1            1                           5
# 39968                  5            1                         240
#
#         Arrival Delay in Minutes             satisfaction  class
# 62305                        0.0                satisfied      1
# 60508                       20.0  neutral or dissatisfied      1
# 100718                       0.0  neutral or dissatisfied      1
# 103587                       0.0  neutral or dissatisfied      1
# 6786                        14.0                satisfied      1
# 70969                       10.0  neutral or dissatisfied      1
# 4185                         0.0  neutral or dissatisfied      1
# 27067                        0.0                satisfied      1
# 55447                        0.0                satisfied      1
# 39968                      242.0  neutral or dissatisfied      1
#
# [10 rows x 23 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                             0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# satisfaction                           0
# class                                  0
# dtype: int64
