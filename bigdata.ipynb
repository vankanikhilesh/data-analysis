# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=648ae66d260b42a3da244ae3e17b93dd131513a3d2d57134b7fce8bdd7a8c1b0
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
import numpy as np
volume_data=np.random.rand(1000000)
print("Volume of data:",len(volume_data))

# %%
import time
#simulate streaming data for every 10 seconds
for i in range(10):
  velocity_data=np.random.rand()
  print(velocity_data)
  time.sleep(2)
# Out:
# 0.6521420708535932
# 0.7789279909325367
# 0.5447464792612459
# 0.6691332921556746
# 0.7693070766778286
# 0.32006919339181217
# 0.28730321297404526
# 0.6969808958626533
# 0.5136661193441125
# 0.6550559053697904

# %%
#structured data
structured_data={'id':1,'name':'john','age':30}
print(structured_data)
#semi structured data
semi_structured_data={'person':{'name':'alice','age':19,'city':'newlands'}}
print(semi_structured_data)
#unstructured data
unstructured_data="this is samaple text document.it can contan any information in free form"
print(unstructured_data)
# Out:
# {'id': 1, 'name': 'john', 'age': 30}
# {'person': {'name': 'alice', 'age': 19, 'city': 'newlands'}}
# this is samaple text document.it can contan any information in free form

# %%
import random
veracity_data=[random.choice([1,2,3,None]) for _ in range(20)]
print("Veracity data:",veracity_data)
# Out:
# Veracity data: [1, 2, None, 3, None, 1, 2, 2, 2, 2, 2, 3, 2, 1, None, None, None, 1, 2, 3]
